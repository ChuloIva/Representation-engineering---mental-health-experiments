# %%
import re
from pathlib import Path
from typing import Dict, Any, Union

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import requests

# %%
df = pd.read_excel("/home/koalacrown/Desktop/Code/Projects/LLM_threapy/LLM_agumented_therapy/Cogexp/Valence/cognitive_experiment_results007_big_normalised.xlsx")
pivot_norm = (
    df.pivot_table(index="pair",
                   columns="strength",
                   values="valence_norm",
                   aggfunc="mean")
      .sort_index()
)

plt.figure(figsize=(14, 10))
sns.heatmap(
    pivot_norm,
    annot=True,
    fmt=".2f",
    cmap="vlag",
    vmin=0.5, vmax=1.2              # tweak as desired; normed values may exceed 1
)
plt.title("Normalised Valence Intensity by Pair and Strength")
plt.xlabel("Strength")
plt.ylabel("Cognitive Pair")
plt.tight_layout()
plt.show()
